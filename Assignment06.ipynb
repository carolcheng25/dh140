# %%
import requests

# %%
response = requests.get('https://www.gutenberg.org/cache/epub/2265/pg2265.txt')

# %%
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
html_string = response.text
text = BeautifulSoup(html_string, "html.parser")

# %%
print(text)
# Out:
# ﻿***The Project Gutenberg's Etext of Shakespeare's First Folio***
# *********************The Tragedie of Hamlet*********************
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#100) at https://www.gutenberg.org/ebooks/100
# *******************************************************************
#
#
# This is our 3rd edition of most of these plays.  See the index.
#
#
# Copyright laws are changing all over the world, be sure to check
# the copyright laws for your country before posting these files!!
#
# Please take a look at the important information in this header.
# We encourage you to keep this file on your own disk, keeping an
# electronic path open for the next readers.  Do not remove this.
#
#
# ...

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent = sent_tokenize(html_string)
print(sent)
# Out:
# ["\ufeff***The Project Gutenberg's Etext of Shakespeare's First Folio***\r\n*********************The Tragedie of Hamlet*********************\r\n\r\n\r\n*******************************************************************\r\nTHIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A\r\nTIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED.", 'THERE\r\nIS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK\r\n(#100) at https://www.gutenberg.org/ebooks/100\r\n*******************************************************************\r\n\r\n\r\nThis is our 3rd edition of most of these plays.', 'See the index.', 'Copyright laws are changing all over the world, be sure to check\r\nthe copyright laws for your country before posting these files!!', 'Please take a look at the important information in this header.', 'We encourage you to keep this file on your own disk, keeping an\r\nelectronic path open for the next readers.', 'Do not remove this.', '**Welcome To The World o
# ...

# %%
words = []
for s in sent:
    for w in word_tokenize(s):
        words.append(w)

# %%
print(words)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
from nltk.corpus import stopwords
from string import punctuation
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
print(list(punctuation))
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
myStopWords = list(punctuation) + stopwords.words('english')

# %%
print(words)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
wordsNoStop = []
for i in words:
    if i not in myStopWords:
        wordsNoStop.append(i)
print(words)
print(wordsNoStop)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(wordsNoStop)

# %%
freq
# Out:
# FreqDist({'I': 563, 'Ham': 337, 'And': 257, 'Lord': 211, "'d": 200, 'King': 173, 'haue': 158, 'The': 151, "'s": 141, 'That': 120, ...})

# %%
for i in sorted(freq, key=freq.get, reverse=True)[:20]:
    print(i,freq[i])
# Out:
# I 563
# Ham 337
# And 257
# Lord 211
# 'd 200
# King 173
# haue 158
# The 151
# 's 141
# That 120
# To 115
# Hamlet 105
# But 104
# shall 104
# What 96
# Hor 95
# thou 90
# thy 83
# Enter 82
# good 77

# %% [markdown]
# # Step Three

# %% [markdown]
# Find your favorite restaurant on Yelp and copy 15 of its reviews into your notebook as Python strings
# <p>You don't have to use requests for this, you can just copy and paste from a browser
# <p>Also note the numbers of stars for each review in your notebook
# <p>Use Vader to find the polarity of each review
# Compare Vader's scores against user-specified numbers of stars

# %%
import nltk
from nltk.sentiment import vader
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = vader.SentimentIntensityAnalyzer()

# %%
#4 stars
sia.polarity_scores('I tried the curry nikutama. I am not sure why, but the flavor of the curry nikutama was just not what I was expecting. While it was not bad, I do not think I would get it again.')
# Out:
# {'neg': 0.041, 'neu': 0.855, 'pos': 0.104, 'compound': 0.5096}

# %%
#5 stars
sia.polarity_scores('the noodles were very chewy and cooked perfectly. I enjoyed the broth from the tonkatsu since it was really rich to where the noodles soaked up all that flavor. I especially liked the mushroom tempura since they were very juicy. One thing I wish they had was soy sauce since I like my tempura with soy sauce since it has a stronger flavor than the tempura sauce offered, but that is just a personal preference. Overall this place was very good, probably the next udon place Ive been to yet.')
# Out:
# {'neg': 0.0, 'neu': 0.801, 'pos': 0.199, 'compound': 0.9426}

# %%
#4 stars
sia.polarity_scores('Come here for comforting authentic udon and more deep fried sides you can shake your chopsticks at. After one bad experience the noodles are always chewy and boiled the right amount.')
# Out:
# {'neg': 0.145, 'neu': 0.78, 'pos': 0.075, 'compound': -0.3612}

# %%
#4 stars
sia.polarity_scores('We ordered the Tonkatsu and the Curry Nikutama. Both great flavors, fresh handmade udon noodles. Loved the Tonkatsu broth!!! My only complaint is that the soft boiled egg in the Tonkatsu bowl was hard boiled. Im used to soft boiled eggs but maybe its supposed to be hard boiled. There wasnt a long line like the ones in Honolulu. We got in very quickly.')
# Out:
# {'neg': 0.112, 'neu': 0.793, 'pos': 0.094, 'compound': 0.353}

# %%
#4 stars
sia.polarity_scores('Overall a great spot for a warm, low-key meal! My party of 2 came in around 4 PM on a Saturday and experienced no wait time. In the cafeteria-style line, you first order your soup and they assemble it in front of you')
# Out:
# {'neg': 0.049, 'neu': 0.752, 'pos': 0.199, 'compound': 0.7777}

# %% [markdown]
# # Step 4

# %% [markdown]
# Make 5 strings that contain reviews (3 sentences each) of your favorite movie comedies
# <p>Make 5 strings that contain reviews (3 sentence each) of your favorite movie dramas
# <p>Make a Python list that contains these 10 strings
# <p>Replicate the analysis pipeline from "04_news_topics.ipynb"
# You don't have to open any files
# <p>Instead of using "listOfNews", use your list of movie reviews
# <p>Modify the characters in "extrastop" if you want to
# <p>For the LDA model step, use "num_topics = 2"
# <p>Comment on the words that the model chooses to represent the 2 topics, and whether they match with your split between comedies and dramas

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
extrastop = ['``',"''","'re","'s","'re",'``',"''","'ll","--","\'\'","...",
             "n\'t",'one','would','use','subject','from',"\'m","\'ve"]

# %%
myStopWords = list(punctuation) + stopwords.words('english') + extrastop

# %%
movrev1 = 'Wow!! I still to these days love this movie!! It has a great choice of cast, and a strong storyline. Zach Gal, Ed Helms, Bradley Cooper, and Ken Jong are funny in The Hangover!! I like the part where Mr. Chow says, it’s funny cause he’s fat! Such a good movie!! My favorite character is Chow!! One of the funniest, and most underrated characters for a comedy movie! My second favorite clip from The Hangover is the movie cameo of Mike Tyson punching Allen! But other then that, I did enjoy the movie!! Definitely worth a watch! I do recommend this movie to anybody.'

# %%
movrev2 = 'A very funny comedy that is raunchy, unique and is extremely engaging.'

# %%
movrev3 = 'This movie is very funny from beginning to end.'

# %%
movrev4 = 'The plot of this movie is ridiculously hilarious that you will definitely think this movie is totally crazy and awesome. I cannot explain how this movie is, there is not a word for it in the English language except crazy, ridiculous and hilarious.'

# %%
movrev5 = 'I love this movie so much. My dad showed it to me a few years ago and I have watched it 5 times since then. It is creative and hilarious. It is for sure my favorite comedy. It has everything you want in a comedy: good jokes, creative writing, and a great cast. Just if you have not seen it yet please do. I guarantee you will enjoy yourself.'

# %%
movrev6 = 'THIS MOVIE IS AMAZING!!! I love watching it!'

# %%
movrev7 = 'I saw it with my mom when it just came out. I was pretty young because this is before we had a PC so I was not any older than ten years old.'

# %%
movrev8 = 'Knowing it is the 3rd highest grossing film of all time as of now, I can imagine why! I became so fascinated by the history of the Titanic when I was in 5th grade and was the guy who drew pictures and watched videos about it and read books from the library about it so this movie was meant for people like me.'

# %%
movrev9 = 'This movie is a masterpiece, everything is perfectly and beautifully shot and well acted. The way they recreated the interior of the ship is near perfect and reflects the sheer beauty of the Titanic.'

# %%
movrev10 = 'The quintessential tragedy and romance film everyone should watch at least once in their lifetime.Beautifully scored, written and produced, the relevance of Titanic remains, 23 years later. Precisely crafted with stunningly accurate historical detail and unmissable cinematography, combined with actors Leonardo DiCaprio and Kate Winslets stunningly beautiful performance, where both actors were wonderfully suited to their roles.'

# %%
listOfMovieReviews = [movrev1, movrev2, movrev3, movrev4, movrev5, movrev6, movrev7, movrev8, movrev9, movrev10]

# %%
print(listOfMovieReviews)
# Out:
# ['Wow!! I still to these days love this movie!! It has a great choice of cast, and a strong storyline. Zach Gal, Ed Helms, Bradley Cooper, and Ken Jong are funny in The Hangover!! I like the part where Mr. Chow says, it’s funny cause he’s fat! Such a good movie!! My favorite character is Chow!! One of the funniest, and most underrated characters for a comedy movie! My second favorite clip from The Hangover is the movie cameo of Mike Tyson punching Allen! But other then that, I did enjoy the movie!! Definitely worth a watch! I do recommend this movie to anybody.', 'A very funny comedy that is raunchy, unique and is extremely engaging.', 'This movie is very funny from beginning to end.', 'The plot of this movie is ridiculously hilarious that you will definitely think this movie is totally crazy and awesome. I cannot explain how this movie is, there is not a word for it in the English language except crazy, ridiculous and hilarious.', 'I love this movie so much. My dad showed it to me a
# ...

# %%
listOfMovieWords = []
for i in listOfMovieReviews:
    listOfMovieWords.append([w for w in word_tokenize(i.lower()) if w not in myStopWords])

# %%
listOfMovieWords
# Out:
# [['wow',
#   'still',
#   'days',
#   'love',
#   'movie',
#   'great',
#   'choice',
#   'cast',
#   'strong',
#   'storyline',
#   'zach',
#   'gal',
#   'ed',
#   'helms',
#   'bradley',
#   'cooper',
#   'ken',
#   'jong',
#   'funny',
#   'hangover',
#   'like',
#   'part',
#   'mr.',
#   'chow',
#   'says',
#   '’',
#   'funny',
#   'cause',
#   '’',
#   'fat',
#   'good',
#   'movie',
#   'favorite',
#   'character',
#   'chow',
#   'funniest',
#   'underrated',
#   'characters',
#   'comedy',
#   'movie',
#   'second',
#   'favorite',
#   'clip',
#   'hangover',
#   'movie',
#   'cameo',
#   'mike',
#   'tyson',
#   'punching',
#   'allen',
#   'enjoy',
#   'movie',
#   'definitely',
#   'worth',
#   'watch',
#   'recommend',
#   'movie',
#   'anybody'],
#  ['funny', 'comedy', 'raunchy', 'unique', 'extremely', 'engaging'],
#  ['movie', 'funny', 'beginning', 'end'],
#  ['plot',
#   'movie',
#   'ridiculously',
#   'hilarious',
#   'definitely',
#   'think',
#   'movie',
# ...

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
listOfStemmedWords = []
for i in listOfMovieWords:
    listOfStemmedWords.append([p_stemmer.stem(w) for w in i])

# %%
# !pip install gensim
# Out:
# ...
#      |████████████████████████████████| 24.0 MB 18.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 2.3 MB/s  eta 0:00:01
# ...

# %%
from gensim import corpora, models
import gensim

# %%
dictionary = corpora.Dictionary(listOfStemmedWords)

# %%
print(dictionary.token2id)
# Out:
# {'allen': 0, 'anybodi': 1, 'bradley': 2, 'cameo': 3, 'cast': 4, 'caus': 5, 'charact': 6, 'choic': 7, 'chow': 8, 'clip': 9, 'comedi': 10, 'cooper': 11, 'day': 12, 'definit': 13, 'ed': 14, 'enjoy': 15, 'fat': 16, 'favorit': 17, 'funni': 18, 'funniest': 19, 'gal': 20, 'good': 21, 'great': 22, 'hangov': 23, 'helm': 24, 'jong': 25, 'ken': 26, 'like': 27, 'love': 28, 'mike': 29, 'movi': 30, 'mr.': 31, 'part': 32, 'punch': 33, 'recommend': 34, 'say': 35, 'second': 36, 'still': 37, 'storylin': 38, 'strong': 39, 'tyson': 40, 'underr': 41, 'watch': 42, 'worth': 43, 'wow': 44, 'zach': 45, '’': 46, 'engag': 47, 'extrem': 48, 'raunchi': 49, 'uniqu': 50, 'begin': 51, 'end': 52, 'awesom': 53, 'crazi': 54, 'english': 55, 'except': 56, 'explain': 57, 'hilari': 58, 'languag': 59, 'plot': 60, 'ridicul': 61, 'think': 62, 'total': 63, 'word': 64, '5': 65, 'ago': 66, 'creativ': 67, 'dad': 68, 'everyth': 69, 'guarante': 70, 'joke': 71, 'much': 72, 'pleas': 73, 'seen': 74, 'show': 75, 'sinc': 76, 'sure': 77
# ...

# %%
corpus = [dictionary.doc2bow(text) for text in listOfStemmedWords]

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus, 
                                           num_topics=2, 
                                           id2word = dictionary, 
                                           passes=20)

# %%
for i in ldamodel.print_topics(num_topics=2, num_words=20):
    print(i)
# Out:
# (0, '0.053*"movi" + 0.023*"comedi" + 0.023*"funni" + 0.018*"favorit" + 0.017*"love" + 0.017*"watch" + 0.013*"’" + 0.013*"hangov" + 0.013*"chow" + 0.013*"charact" + 0.013*"great" + 0.013*"good" + 0.013*"cast" + 0.013*"enjoy" + 0.013*"creativ" + 0.013*"everyth" + 0.013*"beauti" + 0.008*"definit" + 0.008*"like" + 0.008*"time"')
# (1, '0.026*"movi" + 0.015*"watch" + 0.015*"titan" + 0.015*"year" + 0.015*"hilari" + 0.015*"actor" + 0.015*"stunningli" + 0.015*"film" + 0.015*"ridicul" + 0.015*"crazi" + 0.009*"beauti" + 0.009*"time" + 0.009*"quintessenti" + 0.009*"lifetime.beauti" + 0.009*"precis" + 0.009*"later" + 0.009*"23" + 0.009*"everyon" + 0.009*"histor" + 0.009*"relev"')

# %% [markdown]
# Some of the words match up with the movies but some of them are not really descriptive of what the movies are about. They give a slight idea of what kind of movie is being reviewed but some of the words can throw you off.
