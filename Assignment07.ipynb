# %% [markdown]
# # Step 2

# %%
import requests

# %%
response = requests.get('https://www.gutenberg.org/cache/epub/2265/pg2265.txt')

# %%
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
html_string = response.text
text = BeautifulSoup(html_string, "html.parser")

# %%
print(text)
# Out:
# ﻿***The Project Gutenberg's Etext of Shakespeare's First Folio***
# *********************The Tragedie of Hamlet*********************
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#100) at https://www.gutenberg.org/ebooks/100
# *******************************************************************
#
#
# This is our 3rd edition of most of these plays.  See the index.
#
#
# Copyright laws are changing all over the world, be sure to check
# the copyright laws for your country before posting these files!!
#
# Please take a look at the important information in this header.
# We encourage you to keep this file on your own disk, keeping an
# electronic path open for the next readers.  Do not remove this.
#
#
# ...

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent = sent_tokenize(html_string)
print(sent)
# Out:
# ["\ufeff***The Project Gutenberg's Etext of Shakespeare's First Folio***\r\n*********************The Tragedie of Hamlet*********************\r\n\r\n\r\n*******************************************************************\r\nTHIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A\r\nTIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED.", 'THERE\r\nIS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK\r\n(#100) at https://www.gutenberg.org/ebooks/100\r\n*******************************************************************\r\n\r\n\r\nThis is our 3rd edition of most of these plays.', 'See the index.', 'Copyright laws are changing all over the world, be sure to check\r\nthe copyright laws for your country before posting these files!!', 'Please take a look at the important information in this header.', 'We encourage you to keep this file on your own disk, keeping an\r\nelectronic path open for the next readers.', 'Do not remove this.', '**Welcome To The World o
# ...

# %%
words = []
for s in sent:
    for w in word_tokenize(s):
        words.append(w)

# %%
print(words)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
from nltk.corpus import stopwords
from string import punctuation
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
print(list(punctuation))
# Out:
# ['!', '"', '#', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '/', ':', ';', '<', '=', '>', '?', '@', '[', '\\', ']', '^', '_', '`', '{', '|', '}', '~']

# %%
myStopWords = list(punctuation) + stopwords.words('english')

# %%
print(words)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
wordsNoStop = []
for i in words:
    if i not in myStopWords:
        wordsNoStop.append(i)
print(words)
print(wordsNoStop)
# Out:
# ['\ufeff', '*', '*', '*', 'The', 'Project', 'Gutenberg', "'s", 'Etext', 'of', 'Shakespeare', "'s", 'First', 'Folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'The', 'Tragedie', 'of', 'Hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'THIS', 'EBOOK', 'WAS', 'ONE', 'OF', 'PROJECT', 'GUTENBERG', "'S", 'EARLY', 'FILES', 'PRODUCED', 'AT', 'A', 'TIME', 'WHEN', 'PROOFING', 'METHODS', 'AND', 'TOOLS', 'WERE', 'NOT', 'WELL', 'DEVELOPED', '.', 'THERE', 'IS', 'AN', 'IMPROVED', 'EDITION', 'OF', 'THIS', 'TITLE', 'WHICH', 'MAY',
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %%
words = [porter.stem(word) for word in words]

# %%
print(words)
# Out:
# ['\ufeff', '*', '*', '*', 'the', 'project', 'gutenberg', "'s", 'etext', 'of', 'shakespear', "'s", 'first', 'folio', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'the', 'tragedi', 'of', 'hamlet', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', '*', 'thi', 'ebook', 'wa', 'one', 'of', 'project', 'gutenberg', "'s", 'earli', 'file', 'produc', 'at', 'a', 'time', 'when', 'proof', 'method', 'and', 'tool', 'were', 'not', 'well', 'develop', '.', 'there', 'is', 'an', 'improv', 'edit', 'of', 'thi', 'titl', 'which', 'may', 'be', 'view', 'as', 
# ...

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(wordsNoStop)

# %%
freq
# Out:
# FreqDist({'I': 563, 'Ham': 337, 'And': 257, 'Lord': 211, "'d": 200, 'King': 173, 'haue': 158, 'The': 151, "'s": 141, 'That': 120, ...})

# %%
for i in sorted(freq, key=freq.get, reverse=True)[:20]:
    print(i,freq[i])
# Out:
# I 563
# Ham 337
# And 257
# Lord 211
# 'd 200
# King 173
# haue 158
# The 151
# 's 141
# That 120
# To 115
# Hamlet 105
# But 104
# shall 104
# What 96
# Hor 95
# thou 90
# thy 83
# Enter 82
# good 77

# %%
import pandas as pd

# %%
fdist = nltk.FreqDist(wordsNoStop)
df_fdist = pd.DataFrame.from_dict(fdist, orient = 'index')
df_fdist.columns = ['Frequency']
df_fdist.index.name = 'Term'
print(df_fdist)
df_fdist.to_csv()
# Out:
#            Frequency
# Term
# ﻿                  1
# The              151
# Project           30
# Gutenberg         20
# 's               141
# ...              ...
# Peale              1
# Ordenance          1
# FINIS              1
# tragedie           1
# HAMLET             1
#
# [6075 rows x 1 columns]
# ...

# %%
df_fdist.describe()
# Out:
#          Frequency
# count  6075.000000
# mean      3.405761
# std      12.801226
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max     563.000000

# %%
df_fdist.mean()
# Out:
# Frequency    3.405761
# dtype: float64

# %%
df_fdist.median()
# Out:
# Frequency    1.0
# dtype: float64

# %%
df_fdist.mode()
# Out:
#    Frequency
# 0          1

# %%
#I am trimming the very high and very low values based on the summary of the frequency distribution
trimmed = df_fdist[
    (df_fdist["Frequency"] > 20) &
    (df_fdist["Frequency"] < 250)
]
plt.hist(trimmed["Frequency"], bins=50)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df_fdist["Frequency"], bins=50)
plt.show()

# %%
trimmed.describe()
# Out:
#         Frequency
# count  145.000000
# mean    48.048276
# std     34.089207
# min     21.000000
# 25%     25.000000
# 50%     38.000000
# 75%     56.000000
# max    211.000000

# %%
display(trimmed.mean())
display(trimmed.median())
display(trimmed.mode())
# Out:
# Frequency    48.048276
# dtype: float64
# Frequency    38.0
# dtype: float64
#    Frequency
# 0         21

# %% [markdown]
# The trimmed mean has a tighter range than the original and takes out some of the values that heavily skew the overall values

# %% [markdown]
# # Step 3

# %% [markdown]
# Make a scatter plot of the target values vs this feature column's values and comment on how the plotted points match up with the correlation coefficient
# Using this feature and target, perform linear regression with sklearn's LinearRegression
# Print the coefficients of the model
# Plot the linear fit on top of the scatter plot
# Calculate (or output) the mean squared error and R-squared values for your fit
# Try doing linear regression with another variable and check how the new fit's mean squared error and R-squared values change.

# %%
from sklearn import datasets

# %%
df = datasets.load_diabetes(as_frame=True)

# %%
features_df = df.data

# %%
target_df = df.target

# %%
print(df.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
features_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
target_df.describe()
# Out:
# count    442.000000
# mean     152.133484
# std       77.093005
# min       25.000000
# 25%       87.000000
# 50%      140.500000
# 75%      211.500000
# max      346.000000
# Name: target, dtype: float64

# %%
import numpy as np

# %%
for column in features_df.columns:
    print(f"{column}: {np.corrcoef(features_df[column], target_df)[0, 1]}")
# Out:
# age: 0.18788875071891983
# sex: 0.0430619984516054
# bmi: 0.5864501344746891
# bp: 0.4414838489308862
# s1: 0.2120224810145508
# s2: 0.17405358696874249
# s3: -0.39478925067091847
# s4: 0.4304528847447734
# s5: 0.5658834252428094
# s6: 0.3824834842485812

# %%
plt.scatter(
    features_df["bmi"],
    target_df
)
plt.xlabel("bmi")
plt.ylabel("target")
plt.show()

# %% [markdown]
# The plotted points match up with the correlation coefficient because we can see that the graph is positive and the correlation coefficient is also positi

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
results = model.fit(features_df["bmi"].values.reshape(-1, 1), target_df)
print(results.coef_, results.intercept_)
# Out:
# [949.43526038] 152.1334841628967

# %%
plt.scatter(
    features_df["bmi"],
    target_df
)
plt.plot(
    features_df["bmi"],
    features_df["bmi"] * results.coef_[0] + results.intercept_,
    color="red"
)
plt.xlabel("bmi")
plt.ylabel("target")
plt.show()

# %%
print(f"r^2 = {model.score(features_df['bmi'].values.reshape(-1, 1), target_df)}")
# Out:
# r^2 = 0.3439237602253803

# %%
y_pred = features_df["bmi"] * results.coef_[0] + results.intercept_
print(f"MSE = {np.mean((target_df - y_pred)**2)}")
# Out:
# MSE = 3890.456585461273

# %%
plt.scatter(
    features_df["age"],
    target_df
)
plt.xlabel("age")
plt.ylabel("target")
plt.show()

# %%
print(f"r^2 = {model.score(features_df['age'].values.reshape(-1, 1), target_df)}")
# Out:
# r^2 = -0.1235489939745702

# %%
y_pred2 = features_df["sex"] * results.coef_[0] + results.intercept_
print(f"MSE = {np.mean((target_df - y_pred2)**2)}")
# Out:
# MSE = 7669.80996459759
